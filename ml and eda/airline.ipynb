# %%
from IPython.core.display import display, HTML, Javascript

html_contents ="""
<!DOCTYPE html>
<html lang="en">
    <head>
    
    <style>
    
.section2{
    Font-Family: 'Playfair Display', Serif;
    font-style: italic;
    font-weight: bold;
    background: #D9D874;
    color:black;
    text-align: center;
    font-size:30px;
    }
    
.section{
    Font-Family: 'Source Sans Pro', Sans-Serif;
    font-weight: bold;
    font-size:20px;
    color:#a02933;
}

.intro{
    Font-Family: 'Playfair Display', Serif;
    text-align:center;
    font-size:15px;
    color:#4e4151;
    letter-spacing:0.5px;
    
    display:fill;
    background-color:#dbba78;
    padding: 0.8em;
    
    border-style: solid;
    border-color:#4e4151;
    border-radius:10px;     
}

.final{
    Font-Family: 'Playfair Display', Serif;
    text-align:center;
    font-size:15px;
    color:#4e4151;
    letter-spacing:0.5px;
    
    display:fill;
    background-color:#dbba78;
    padding: 0.8em;
    
    border-style: dashed;
    border-color:#4e4151;
    border-radius:10px;     
}

mark {
  Font-Family: 'Playfair Display', Serif;
  font-style: italic;
  background: #a02933;
  font-weight: bold;
  color: #dbba78;
  text-align: center;
  font-size:25px;
  justify-content: center;
}

.intro2 {
       padding: 1rem;
       width: 600px;
       0 5px 15px 0 rgba(0,0,0,0.08);
       border-color:#4e4151;
       border-radius:5px;  
       border-style: dashed;
       background-color:#dbba78;
       font-size:15px;
       font-family: 'Playfair Display', Serif;
       font-weight: none;
       letter-spacing:0.5px;
       text-align: left;
       border-width: 2px;
       color: #4e4151;
  
}

hr { border: 0.2px solid #a02933;
           }
    
    
    </style>
    </head>
    
</html>
"""

HTML(html_contents)
# Out:
# C:\Users\sajal\AppData\Local\Temp\ipykernel_12440\1790931018.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, Javascript
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#
#     <style>
#
# .section2{
#     Font-Family: 'Playfair Display', Serif;
#     font-style: italic;
#     font-weight: bold;
#     background: #D9D874;
#     color:black;
#     text-align: center;
#     font-size:30px;
#     }
#
# .section{
#     Font-Family: 'Source Sans Pro', Sans-Serif;
#     font-weight: bold;
#     font-size:20px;
#     color:#a02933;
# }
#
# .intro{
#     Font-Family: 'Playfair Display', Serif;
#     text-align:center;
#     font-size:15px;
#     color:#4e4151;
#     letter-spacing:0.5px;
#
#     display:fill;
#     background-color:#dbba78;
#     padding: 0.8em;
#
#     border-style: solid;
#     border-color:#4e4151;
#     border-radius:10px;
# }
#
# ...

# %%
from IPython.core.display import display, HTML, Javascript

# ----- Notebook Theme -----
color_map  = ["#bfd3e6", "#9b5b4f", "#4e4151", "#78ccdb", "#E9C9C9", "#909195","#dc1e1e","#a02933","#716807","#E9C9C9"]

prompt = color_map[-1]
main_color = color_map[3]
strong_main_color = color_map[1]
custom_colors = [strong_main_color, main_color]

css_file = ''' 

div #notebook {
background-color: white;
line-height: 20px;
}

#notebook-container {
# %s
margin-top: 2em;
padding-top: 2em;
border-top: 4px solid %s; /* light orange */
-webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5); /* pink */
    box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5); /* pink */
}

div .input {
margin-bottom: 1em;
}

.rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
color: %s; /* light orange */
font-weight: 600;
}

div.input_area {
border: none;
    background-color: %s; /* rgba(229, 143, 101, 0.1); light orange [exactly #E58F65] */
    border-top: 2px solid %s; /* light orange */
}

div.input_prompt {
color: %s; /* light blue */
}

div.output_prompt {
color: %s; /* strong orange */
}

div.cell.selected:before, div.cell.selected.jupyter-soft-selected:before {
background: %s; /* light orange */
}

div.cell.selected, div.cell.selected.jupyter-soft-selected {
    border-color: %s; /* light orange */
}

.edit_mode div.cell.selected:before {
background: %s; /* light orange */
}

.edit_mode div.cell.selected {
border-color: %s; /* light orange */

}
'''
def to_rgb(h): 
    return tuple(int(h[i:i+2], 16) for i in [0, 2, 4])

main_color_rgba = 'rgba(%s, %s, %s, 0.1)' % (to_rgb(main_color[1:]))
open('notebook.css', 'w').write(css_file % ('width: 95%;', main_color, main_color, main_color_rgba, main_color,  main_color, prompt, main_color, main_color, main_color, main_color))

def nb(): 
    return HTML("<style>" + open("notebook.css", "r").read() + "</style>")
nb()
# Out:
# C:\Users\sajal\AppData\Local\Temp\ipykernel_12440\1776349661.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML, Javascript
# <style>
#
# div #notebook {
# background-color: white;
# line-height: 20px;
# }
#
# #notebook-container {
# width: 95%;
# margin-top: 2em;
# padding-top: 2em;
# border-top: 4px solid #78ccdb; /* light orange */
# -webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5); /* pink */
#     box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5); /* pink */
# }
#
# div .input {
# margin-bottom: 1em;
# }
#
# .rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
# color: #78ccdb; /* light orange */
# font-weight: 600;
# }
#
# div.input_area {
# border: none;
# ...

# %%
# linear algebra
import numpy as np 
import pandas as pd

#viz
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno


import matplotlib as mlb
import matplotlib.image as mpimg
from matplotlib.offsetbox import AnnotationBbox, OffsetImage

from IPython.display import display
import os
plt.style.use("seaborn")
# %matplotlib inline  
import warnings
warnings.filterwarnings("ignore")

#theme
theme = ["#DEF5E5", "#459E97", "#4B9ABB","#0A4361","#E68193",]

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

#-------------------------------------
from scipy.stats import shapiro

#-------------------------------------
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

#-------------------------------------
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, f1_score,recall_score, precision_score
from sklearn.metrics import average_precision_score, roc_auc_score, roc_curve, auc

#-------------------------------------
from statsmodels.stats.outliers_influence import variance_inflation_factor

#-------------------------------------
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

#------------------------------------- 
from imblearn.over_sampling import SMOTE, ADASYN, BorderlineSMOTE, SVMSMOTE, RandomOverSampler

import warnings
warnings.filterwarnings("ignore")

# %%
warnings.filterwarnings('ignore') # ignore warnings.
# %config IPCompleter.greedy = True # autocomplete feature.
pd.options.display.max_rows = None # set maximum rows that can be displayed in notebook.
pd.options.display.max_columns = None # set maximum columns that can be displayed in notebook.
pd.options.display.precision = 2 # set the precision of floating point numbers.
# pd.set_option('display.max_colwidth', -1) # will help to show all the text strings in the column.
plt.rcParams['figure.figsize'] = (14,4)
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['figure.frameon'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams["font.family"] = "monospace";

# Color Palettes
colors = ["#bfd3e6", "#9b5b4f", "#4e4151", "#3d85c6", "#bb9c55", "#909195","#dc1e1e","#a02933","#716807","#717cb4"]

# %%
passenger=pd.read_csv(r"D:\data science\airline_passenger_satisfaction.csv", encoding = "utf-8" , sep = ",")

# %%
print('****'*10)
print(f'Dataframe has {passenger.shape[0]} Rows, {passenger.shape[1]} Columns')
print('****'*10)

passenger.head().style.set_properties(**{'background-color': '#A2DBFA',
                                    'color': 'black',
                                    'border': '1.5px  solid black'}).bar(color='#F3F1F5', 
                                                                         vmin=100_000, 
                                                                        )
# Out:
# ****************************************
# Dataframe has 129880 Rows, 24 Columns
# ****************************************
# <style type="text/css">
# ...

# %%
passenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
#describe the data with some visual style by applying T = Transpose and st#this gives us some general information on the dataset
#it shows us the count of each value, the mean of each value, standard deviation, percentiles and min/max valuesyle
passenger.describe().T.style.bar(subset=['mean'], color='#E68193')\
                            .background_gradient(subset=['std'], cmap='mako_r')\
                             .background_gradient(subset=['50%'], cmap='mako')
# Out:
# <style type="text/css">
# #T_0b488_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #E68193 100.0%, transparent 100.0%);
# }
# #T_0b488_row0_col2, #T_0b488_row1_col5, #T_0b488_row3_col5, #T_0b488_row4_col5, #T_0b488_row5_col5, #T_0b488_row6_col5, #T_0b488_row7_col5, #T_0b488_row8_col5, #T_0b488_row9_col5, #T_0b488_row10_col5, #T_0b488_row11_col5, #T_0b488_row12_col5, #T_0b488_row13_col5, #T_0b488_row14_col5, #T_0b488_row15_col5, #T_0b488_row16_col5, #T_0b488_row17_col5, #T_0b488_row18_col5 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_0b488_row0_col5, #T_0b488_row1_col2, #T_0b488_row3_col2, #T_0b488_row4_col2, #T_0b488_row5_col2, #T_0b488_row6_col2, #T_0b488_row7_col2, #T_0b488_row8_col2, #T_0b488_row9_col2, #T_0b488_row10_col2, #T_0b488_row11_col2, #T_0b488_row12_col2, #T_0b488_row13_col2, #T_0b488_row14_col2, #T_0b488_row15_col2, #T_0b488_row16_col2, #T_0b488_row17_col2, #T_0b488_row18_col2 {
#   background-color: #def5e5;
#   color: #000000;
# }
# ...

# %%
passenger.drop(["ID"],axis=1,inplace=True)

# %%
passenger.dropna(axis=0, how="all", subset=passenger.columns[1:], inplace=True)

# %%
msno.bar(passenger,figsize=(15, 5),fontsize=10,color = '#459E97');

# %%
missing = passenger.isnull().sum()
missing = missing[missing > 0]
missing = missing.sort_values(ascending = False)
missing
# Out:
# Arrival Delay    393
# dtype: int64

# %%
numeric_data=passenger.select_dtypes(exclude=["category"])
numeric_data.plot(subplots =True, kind = 'box', layout = (5,5), figsize = (14,14),patch_artist=True,color="#459E97")
plt.subplots_adjust(wspace = 0.5)

# %%
numeric_data=passenger.select_dtypes(exclude=["category"])
numeric_feature = passenger.dtypes!=object
final_numeric_feature = passenger.columns[numeric_feature].tolist()

# %%
for i in range(len(final_numeric_feature)):
    stat,p = shapiro(passenger[final_numeric_feature[i]])
    print(final_numeric_feature[i])
    print('P_value=%.3f' % (p))
    print("*******************************")
# Out:
# Age
# P_value=0.000
# *******************************
# Flight Distance
# P_value=0.000
# *******************************
# Departure Delay
# P_value=0.000
# *******************************
# Arrival Delay
# P_value=1.000
# *******************************
# Departure and Arrival Time Convenience
# P_value=0.000
# *******************************
# Ease of Online Booking
# P_value=0.000
# *******************************
# Check-in Service
# P_value=0.000
# *******************************
# Online Boarding
# P_value=0.000
# *******************************
# Gate Location
# P_value=0.000
# *******************************
# On-board Service
# P_value=0.000
# *******************************
# Seat Comfort
# P_value=0.000
# *******************************
# Leg Room Service
# P_value=0.000
# *******************************
# Cleanliness
# P_value=0.000
# *******************************
# Food and Drink
# P_value=0.000
# *******************************
# In-flight Service
# P_value=0.000
# ...

# %%
def out_lairs(col):
    """
    this function take the name of column and compute the median(Q2)represent 50% percentage
    and also compute the Q3(75%)from the boxblot then compute the inter_quantile_range 
    and then we compute the upper limit and the lowerlimit to show the origin of the outlairs
    
    """
    Q1 = passenger[col].quantile(0.25)
    Q3 =  passenger[col].quantile(0.75)
    IQR = Q3-Q1
    data_out = passenger.loc[(passenger[col] < (Q1-1.5*IQR)) | (passenger[col] > (Q3+1.5*IQR))][:10]
    
    return data_out

# %%
out_lairs("Flight Distance")
# Out:
#      Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 5      Male   43     Returning       Business  Business             3788
# 58   Female   41     Returning       Business  Business             3997
# 148    Male   37     Returning       Business  Business             3758
# 173  Female   39     Returning       Business  Business             3822
# 185    Male   42     Returning       Business  Business             3880
# 198  Female   60     Returning       Business  Business             3756
# 254    Male   26     Returning       Business  Business             3800
# 263  Female   43     Returning       Business  Business             3967
# 325  Female   31     Returning       Business  Business             3845
# 328    Male   47     Returning       Business  Business             3954
#
#      Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 5                  0            0.0                                       4
# ...

# %%
out_lairs("Departure Delay")
# Out:
#     Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 13    Male    9     Returning       Personal  Business              853
# 40  Female   54     Returning       Business  Business             1554
# 54    Male   36     Returning       Business  Business             3655
# 61    Male   31     Returning       Business   Economy              173
# 69  Female   49     Returning       Business  Business             3213
# 76  Female   72    First-time       Business   Economy               67
# 78  Female   70     Returning       Personal   Economy              108
# 79  Female   46     Returning       Personal   Economy              173
# 82    Male   58     Returning       Personal   Economy              215
# 89    Male   41     Returning       Business  Business             2865
#
#     Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 13               68           76.0                                       5
# ...

# %%
out_lairs("Arrival Delay")
# Out:
#     Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 1   Female   35     Returning       Business  Business              821
# 13    Male    9     Returning       Personal  Business              853
# 28    Male   40     Returning       Business  Business             3734
# 40  Female   54     Returning       Business  Business             1554
# 47  Female   40    First-time       Business  Business              212
# 54    Male   36     Returning       Business  Business             3655
# 59    Male   57     Returning       Business  Business             3392
# 61    Male   31     Returning       Business   Economy              173
# 68    Male   52     Returning       Business  Business              212
# 69  Female   49     Returning       Business  Business             3213
#
#     Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 1                26           39.0                                       2
# ...

# %%
#cuz of skewing  and outlairs we are gonna impute with median
passenger['Arrival Delay'] = passenger['Arrival Delay'].fillna(passenger['Arrival Delay'].median())

# %%
#lets convert it into ordinal variables
pare=["Ease of Online Booking","Check-in Service" ,"Online Boarding","Gate Location" ,"Leg Room Service","Cleanliness","Food and Drink" ,"In-flight Service" ,"In-flight Wifi Service" ,"In-flight Entertainment" ,"Baggage Handling","Seat Comfort","On-board Service","Departure and Arrival Time Convenience"]
for i in pare:
    passenger[i]=passenger[i].astype(object)

# %%
unique_values = {column: list(passenger[column].unique()) for column in passenger.select_dtypes(object).columns}
for key, value in unique_values.items():
    print(f'{key} : {value}')
# Out:
# Gender : ['Male', 'Female']
# Customer Type : ['First-time', 'Returning']
# Type of Travel : ['Business', 'Personal']
# Class : ['Business', 'Economy', 'Economy Plus']
# Departure and Arrival Time Convenience : [3, 2, 4, 1, 5, 0]
# Ease of Online Booking : [3, 2, 4, 1, 5, 0]
# Check-in Service : [4, 3, 1, 2, 5, 0]
# Online Boarding : [3, 5, 4, 2, 1, 0]
# Gate Location : [3, 2, 4, 1, 5, 0]
# On-board Service : [3, 5, 4, 2, 1, 0]
# Seat Comfort : [5, 4, 3, 2, 1, 0]
# Leg Room Service : [2, 5, 3, 4, 1, 0]
# Cleanliness : [5, 4, 3, 2, 1, 0]
# Food and Drink : [5, 3, 4, 2, 1, 0]
# In-flight Service : [5, 3, 4, 1, 2, 0]
# In-flight Wifi Service : [3, 2, 4, 1, 0, 5]
# In-flight Entertainment : [5, 3, 4, 2, 1, 0]
# Baggage Handling : [5, 3, 4, 1, 2]
# Satisfaction : ['Neutral or Dissatisfied', 'Satisfied']

# %%
numeric_values = {column for column in passenger.select_dtypes(int).columns}
numeric_values=list(numeric_values)
numeric_values
# Out:
# ['Flight Distance', 'Age', 'Departure Delay']

# %%
#df_dumpassmy.loc[passenger.duplicated()].shape

# %%
mask = np.zeros_like(passenger.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)]= True


fig, ax = plt.subplots(figsize=(13, 13))

heatmap = sns.heatmap(passenger.corr(),
                      mask = mask,
                      square = True,
                      linewidths = .5,
                      cmap = 'PuBuGn',
                      cbar_kws = {'shrink': .4,"ticks" : [-1, -.5, 0, 0.5, 1]},
                      vmin = -1,
                      vmax = 1,
                      annot = True,
                      annot_kws = {"size": 12})

#add the column names as labels
ax.set_yticklabels(passenger.corr(), rotation = 0)
ax.set_xticklabels(passenger.corr())

sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

ax.annotate('correlation',
                    fontsize=10,fontweight='bold',
                    xy=(2.3, 4.2), xycoords='data',
                    xytext=(0.6, 0.95), textcoords='axes fraction',
                    arrowprops=dict(
                    facecolor=theme[4], shrink=0.025, 
                    connectionstyle='arc3, rad=0.80'),
                    horizontalalignment='left', verticalalignment='top'
)

ax.set_title('Correlation of Features', size = 22, color = theme[3], weight='bold', pad=20)
# Out:
# Text(0.5, 1.0, 'Correlation of Features')

# %%
sns.set_context('poster', font_scale= 0.6)
fig, ax  = plt.subplots(1, 3, figsize=(20, 6))

plt.suptitle('Histograms of all Numerical Features', fontsize = 20)

ax1 = sns.histplot(x = passenger['Age'], hue= passenger['Satisfaction'], ax= ax[0], bins= 15, kde= True, palette= 'husl')
ax1.set(xlabel= 'Age', ylabel= 'Frequency')

ax2 = sns.histplot(x = passenger['Departure Delay'], hue= passenger['Satisfaction'], ax= ax[1], bins= 15, kde= True, palette= 'husl')
ax2.set(xlabel= 'Departure Delay', ylabel= 'Frequency')

ax3 = sns.histplot(x = passenger['Flight Distance'], hue= passenger['Satisfaction'], ax= ax[2], bins= 15, kde= True, palette= 'husl')
ax3.set(xlabel= 'Flight Distance', ylabel= 'Frequency')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 10))
plt.suptitle('Count plot for nominal categorical features', fontsize = 30)

ax1 = sns.countplot(x ='Gender', data= passenger, hue= 'Satisfaction', ax= ax[0, 0], palette="husl" )
ax1.set(xlabel = 'Gender')

ax2 = sns.countplot(x ='Customer Type', data= passenger, hue= 'Satisfaction', ax= ax[0, 1], palette= "husl")
ax2.set(xlabel = 'Customer Type')

ax3 = sns.countplot(x ='Class', data= passenger, hue= 'Satisfaction', ax= ax[1, 0],  palette="husl")
ax3.set(xlabel = 'Class')

ax4 = sns.countplot(x ='Type of Travel', data= passenger, hue= 'Satisfaction', ax= ax[1, 1], palette="husl")
ax4.set(xlabel = 'Type of Travel')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(6, 2, figsize = (20,20))
plt.suptitle('Count plot for Ordinal categorical features', fontsize = 30)

ax1 = sns.countplot(x ='Ease of Online Booking', data= passenger, hue= 'Satisfaction', ax= ax[0, 0], palette="husl" )
ax1.set(xlabel = 'Ease of Online Booking')

ax2 = sns.countplot(x ='Check-in Service', data= passenger, hue= 'Satisfaction', ax= ax[0, 1], palette= "husl")
ax2.set(xlabel = 'Check-in Service')

ax3 = sns.countplot(x ='Online Boarding', data= passenger, hue= 'Satisfaction', ax= ax[1, 0],  palette="husl")
ax3.set(xlabel = 'Online Boarding')

ax4 = sns.countplot(x ='Gate Location', data= passenger, hue= 'Satisfaction', ax= ax[1, 1], palette="husl")
ax4.set(xlabel = 'Gate Location')

ax5 = sns.countplot(x ='Leg Room Service', data= passenger, hue= 'Satisfaction', ax= ax[2, 0], palette="husl" )
ax5.set(xlabel = 'Leg Room Service')

ax6 = sns.countplot(x ='Cleanliness', data= passenger, hue= 'Satisfaction', ax= ax[2, 1], palette= "husl")
ax6.set(xlabel = 'Cleanliness')

ax7 = sns.countplot(x ='Food and Drink', data= passenger, hue= 'Satisfaction', ax= ax[3, 0],  palette="husl")
ax7.set(xlabel = "Food and Drink")

ax8 = sns.countplot(x ='In-flight Service', data= passenger, hue= 'Satisfaction', ax= ax[3, 1], palette="husl")
ax8.set(xlabel = 'In-flight Service')

ax9 = sns.countplot(x ='In-flight Entertainment', data= passenger, hue= 'Satisfaction', ax= ax[4, 0],  palette="husl")
ax9.set(xlabel = "In-flight Entertainment")

ax10 = sns.countplot(x ='Baggage Handling', data= passenger, hue= 'Satisfaction', ax= ax[4, 1], palette="husl")
ax10.set(xlabel = 'Baggage Handling')

ax11 = sns.countplot(x ='In-flight Wifi Service', data= passenger, hue= 'Satisfaction', ax= ax[5, 0], palette="husl")
ax11.set(xlabel = 'In-flight Wifi Service');

# %%
#plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 8))
fig.suptitle(' propability of Satisfaction ', size = 26, color = theme[3], weight='bold')
axs = [ax1, ax2]

#Count-Plot
sns.countplot(passenger['Satisfaction'], ax=ax1, palette='husl')
ax1.set_title('Count Plot', size = 14, color = theme[3], weight='bold', pad=20)



#Data-2
names = ["Neutral or Dissatisfied", "Satisfied"]
values = passenger['Satisfaction'].value_counts()
colors = ["#E68193","#459E97"]
explode = (0.01, 0.01)

#Doughnut-chart
ax2.pie(x= values,labels =names, colors=colors,autopct='%1.0f%%', pctdistance=0.8,explode=explode,shadow= True);

# %%
passenger["Age"].unique()
# Out:
# array([48, 35, 41, 50, 49, 43, 60, 38, 28, 27, 24,  9, 52, 70, 61, 11, 42,
#        14, 56, 77, 51, 47, 58, 40, 21, 33, 39, 54, 46, 45, 23, 20, 44, 37,
#        36, 57, 31, 53, 25, 55, 72, 19, 65, 32, 80,  7, 34, 18, 12, 26, 17,
#        66, 68, 67, 59, 69, 16, 22, 64, 29, 10, 71, 30, 62, 63,  8, 15, 73,
#        78, 74, 79, 13, 76, 75, 85], dtype=int64)

# %%
passenger["Age_cat"]=pd.cut(passenger["Age"],bins=[0,20,40,60,80,100],right=False)

# %%
 sns.countplot(x ='Age_cat', data= passenger, hue= 'Satisfaction',palette="husl")
# Out:
# <AxesSubplot:xlabel='Age_cat', ylabel='count'>

# %%
passenger["Flight Distance"].mean()
# Out:
# 1190.3163920542038

# %%
passenger[passenger["In-flight Wifi Service"]==5].head(10)
# Out:
#      Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 35   Female   42     Returning       Business  Business             2884
# 72     Male   70     Returning       Business   Economy              173
# 75     Male   55    First-time       Business   Economy              108
# 78   Female   70     Returning       Personal   Economy              108
# 83   Female    9     Returning       Personal   Economy              173
# 91   Female   50     Returning       Business  Business             2035
# 98   Female   52     Returning       Business  Business              562
# 109  Female   27    First-time       Business  Business              562
# 117    Male   32     Returning       Business  Business              562
# 136  Female   45     Returning       Business  Business              227
#
#      Departure Delay  Arrival Delay Departure and Arrival Time Convenience  \
# 35                 0            0.0                                      2
# ...

# %%
passenger[passenger["Age"]==70].head()
# Out:
#      Gender  Age Customer Type Type of Travel    Class  Flight Distance  \
# 15     Male   70     Returning       Personal  Economy              821
# 21   Female   70     Returning       Personal  Economy              853
# 72     Male   70     Returning       Business  Economy              173
# 78   Female   70     Returning       Personal  Economy              108
# 249  Female   70     Returning       Personal  Economy              719
#
#      Departure Delay  Arrival Delay Departure and Arrival Time Convenience  \
# 15                 0            0.0                                      5
# 21                 0            0.0                                      4
# 72                 0            0.0                                      5
# 78                50           41.0                                      4
# 249                0            0.0                                      4
#
#     Ease of Online Booking Check-in Service Online Boarding Gate Location  \
# ...

# %%
sns.countplot(x ='Age_cat', data= passenger, hue= 'In-flight Wifi Service')
# Out:
# <AxesSubplot:xlabel='Age_cat', ylabel='count'>

# %%
sns.relplot(x="Departure Delay",y='Arrival Delay',data=passenger,col="Satisfaction",col_wrap=2, palette="husl")

# %%
#lets handle the skewing of the features
# Create a list of float colums to check for skewing
mask = passenger.dtypes == np.float
float_cols = passenger.columns[mask]

skew_limit = 0.75 # define a limit above which we will log transform
skew_vals = passenger[float_cols].skew()

# %%
# Showing the skewed columns
skew_cols = (skew_vals
             .sort_values(ascending=False)
             .to_frame()
             .rename(columns={0:'Skew'})
             .query('abs(Skew) > {}'.format(skew_limit)))

# %%
sns.set(rc={'figure.figsize':(3,5)})
plt.xticks(fontsize=12,rotation='vertical')
p=sns.barplot(x=skew_cols.index, y="Skew", data=skew_cols,palette="Greens",capsize=.1)
p.axes.set_title("\nSkew Columns\n",fontsize=30);

# %%
passenger["Arrival Delay"] = passenger["Arrival Delay"] .apply(np.log1p)

# %%
import sklearn
# For splitting, scaling and upsampling the data respectively
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder,OrdinalEncoder
from sklearn.utils import resample

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# For Evaluation 
from sklearn.metrics import classification_report, confusion_matrix

# %%
unique_values = {column: list(passenger[column].unique()) for column in passenger.select_dtypes(object).columns}
for key, value in unique_values.items():
    print(f'{key} : {value}')
# Out:
# Gender : ['Male', 'Female']
# Customer Type : ['First-time', 'Returning']
# Type of Travel : ['Business', 'Personal']
# Class : ['Business', 'Economy', 'Economy Plus']
# Departure and Arrival Time Convenience : [3, 2, 4, 1, 5, 0]
# Ease of Online Booking : [3, 2, 4, 1, 5, 0]
# Check-in Service : [4, 3, 1, 2, 5, 0]
# Online Boarding : [3, 5, 4, 2, 1, 0]
# Gate Location : [3, 2, 4, 1, 5, 0]
# On-board Service : [3, 5, 4, 2, 1, 0]
# Seat Comfort : [5, 4, 3, 2, 1, 0]
# Leg Room Service : [2, 5, 3, 4, 1, 0]
# Cleanliness : [5, 4, 3, 2, 1, 0]
# Food and Drink : [5, 3, 4, 2, 1, 0]
# In-flight Service : [5, 3, 4, 1, 2, 0]
# In-flight Wifi Service : [3, 2, 4, 1, 0, 5]
# In-flight Entertainment : [5, 3, 4, 2, 1, 0]
# Baggage Handling : [5, 3, 4, 1, 2]
# Satisfaction : ['Neutral or Dissatisfied', 'Satisfied']

# %%
class_encod = ['Business', 'Economy', 'Economy Plus']                
passenger['Class'] = passenger['Class'].apply(lambda x: class_encod.index(x))

# %%
pare=["Ease of Online Booking","Check-in Service" ,"Online Boarding","Gate Location" ,"Leg Room Service","Cleanliness","Food and Drink" ,"In-flight Service" ,"In-flight Wifi Service" ,"In-flight Entertainment" ,"Baggage Handling","Seat Comfort","On-board Service","Departure and Arrival Time Convenience"]
for i in pare:
    passenger[i]=passenger[i].astype(int)

# %%
binary_columns = ['Gender', 'Customer Type', 'Satisfaction', 'Type of Travel']                  
le = LabelEncoder()
for column in binary_columns:
    passenger[column] = le.fit_transform(passenger[column])

# %%
passenger.head()
# Out:
#    Gender  Age  Customer Type  Type of Travel  Class  Flight Distance  \
# 0       1   48              0               0      0              821
# 1       0   35              1               0      0              821
# 2       1   41              1               0      0              853
# 3       1   50              1               0      0             1905
# 4       0   49              1               0      0             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2           1.79                                       3
# 1               26           3.69                                       2
# 2                0           0.00                                       4
# 3                0           0.00                                       2
# 4                0           0.69                                       3
#
#    Ease of Online Booking  Check-in Service  Online Boarding  Gate Location  \
# ...

# %%
passenger.drop(["Age_cat"],axis=1,inplace=True)

# %%
x = passenger.drop("Satisfaction", axis = 1)
y = passenger['Satisfaction']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state =100 ,stratify=y, test_size = 0.2)
print(y_train.value_counts())
# Out:
# 0    58762
# 1    45142
# Name: Satisfaction, dtype: int64

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
#split
from sklearn.model_selection import train_test_split

#score
from sklearn.metrics import precision_score, accuracy_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import plot_roc_curve
#models
from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier, Perceptron, PassiveAggressiveClassifier
from sklearn.svm import SVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.neighbors import NearestCentroid,KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier

#Hyper-Parameter-Tuning
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
models = [
    ('Logistic Regression', LogisticRegression(max_iter=1000)),
    ('Support Vector Classifier', SVC()),
    ('Decision Tree', DecisionTreeClassifier()),
    ('Random Forest Classifier', RandomForestClassifier()),
   
    
]

results = dict()
for name, model in models:

      model.fit(x_train, y_train)
      pred = model.predict(x_test)
      score = accuracy_score(y_test, pred)
      print(classification_report(y_test, pred))
      from sklearn import metrics 
      from sklearn.metrics import roc_curve, auc

      auc_roc=metrics.roc_auc_score(y_test,pred)
      print(auc_roc)


     
      mae = mean_absolute_error(y_test, pred)
      mse = mean_squared_error(y_test, pred)
      rmse = np.sqrt(mean_squared_error(y_test, pred))
      precision = precision_score(y_test, pred) 
      results[name] = score
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     14690
#            1       0.87      0.84      0.86     11286
#
#     accuracy                           0.88     25976
#    macro avg       0.88      0.87      0.88     25976
# weighted avg       0.88      0.88      0.88     25976
#
# 0.8736459033384977
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     14690
#            1       0.96      0.94      0.95     11286
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976
#
# 0.9583627830018142
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96     14690
#            1       0.94      0.94      0.94     11286
#
#     accuracy                           0.95     25976
# ...

# %%
#storing the results into dataframe
df_results = pd.DataFrame([results])
df_results = df_results.transpose()
df_results = df_results.rename(columns={0:'Score'}).sort_values(by='Score',ascending=False)

# %%
df_results.columns
# Out:
# Index(['Score'], dtype='object')

# %%
df_results.style.set_properties(**{'background-color': '#DEF5E5',
                                    'color': 'black',
                                    'border': '0.5px  solid black'})
# Out:
# <style type="text/css">
# #T_78278_row0_col0, #T_78278_row1_col0, #T_78278_row2_col0, #T_78278_row3_col0 {
#   background-color: #DEF5E5;
#   color: black;
#   border: 0.5px  solid black;
# }
# </style>
# <table id="T_78278">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78278_level0_col0" class="col_heading level0 col0" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78278_level0_row0" class="row_heading level0 row0" >Random Forest Classifier</th>
#       <td id="T_78278_row0_col0" class="data row0 col0" >0.966777</td>
#     </tr>
#     <tr>
#       <th id="T_78278_level0_row1" class="row_heading level0 row1" >Support Vector Classifier</th>
#       <td id="T_78278_row1_col0" class="data row1 col0" >0.960117</td>
#     </tr>
#     <tr>
#       <th id="T_78278_level0_row2" class="row_heading level0 row2" >Decision Tree</th>
#       <td id="T_78278_row2_col0" class="data row2 col0" >0.949261</td>
#     </tr>
# ...

# %%
fig = plt.figure(figsize=(10,5))

ax = sns.barplot(data=df_results, 
                 y=df_results.index, 
                 x='Score',
                 color=theme[4],
                 saturation=0.8,
                 edgecolor=theme[4],
                 linewidth=0.1)

ax.figure.suptitle('Models',y=1.00, size = 26, color = theme[3], weight='bold');
ax.text(x = 0.6, y = 0.12, s = 'Best Model', fontsize=15, weight = 'bold',color=theme[0])


plt.xlabel('Score')
plt.ylabel('Models')
plt.axvline(x = 0.691, ymin = 0, ymax = 1,
            linewidth = 2, linestyle ="--",
            color ='#459E97');

# %%
import numpy as np
fig,ax = plt.subplots(figsize=(4,4))
confusion_matrix=metrics.confusion_matrix(y_test,pred)
ax= sns.heatmap(confusion_matrix,
                annot = True,
                cbar= True,
                fmt='g',
               cmap= theme)
plt.xlabel('True Label')
plt.ylabel('Predicted Label')
plt.title('Confusion-Matrix')
plt.tight_layout()  
plt.show()

# %%
rlf=RandomForestClassifier()
rlf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_prob = rlf.predict_proba(x_test)[:,1]
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')
